# %%
import optuna
import pandas as pd
import numpy as np
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

# %%
# Load dataset
train = pd.read_csv('train.csv')

# %%
# def NDVI(df):
#     NDVI_series = (df['b8'] - df['b4']) / (df['b8'] + df['b4'])
#     return NDVI_series
    
# def Moisture_index(df):
#     Moist = (df['b8_a'] - df['b11']) / (df['b8_a'] + df['b11'])
#     return Moist

def NDWI(df):
    NDWI_series = (df['b3'] - df['b8']) / (df['b3'] + df['b8'])
    return NDWI_series

def NDSI(df):
    NDSI_series = (df['b3'] - df['b11']) / (df['b3'] + df['b11'])
    return NDSI_series

def BSI(df):
    bsi_index = ((df['b11'] + df['b4']) - (df['b8'] + df['b2'])) / ((df['b11'] + df['b4']) + (df['b8'] + df['b2']))
    return bsi_index
    
def NBR1(df):
    return (df['b8'] - df['b11']) / (df['b8'] + df['b11'])

def NBR3(df):
    return (df['b8'] - df['b12']) / (df['b8'] + df['b12'])

def NBR4(df):
    return (df['b8_a'] - df['b12']) / (df['b8_a'] + df['b12'])

def AFRI1(df):
    return (df['b8'] - (0.66 * df['b11'])) / (df['b8'] + (0.66 * df['b11']))

def AFRI2(df):
    return (df['b8_a'] - (0.66 * df['b11'])) / (df['b8_a'] + (0.66 * df['b11']))

def AFRI3(df):
    return (df['b8'] - (0.66 * df['b12'])) / (df['b8'] + (0.66 * df['b12']))

def AFRI4(df):
    return (df['b8_a'] - (0.66 * df['b12'])) / (df['b8_a'] + (0.66 * df['b12']))

def BNDVI1(df):
    return (df['b8'] - df['b2']) / (df['b8'] + df['b2'])

def BNDVI2(df):
    return (df['b8_a'] - df['b2']) / (df['b8_a'] + df['b2'])

def BWDRVI1(df):
    return ((0.1 * df['b8']) - df['b2']) / ((0.1 * df['b8']) + df['b2'])

def BWDRVI2(df):
    return ((0.1 * df['b8_a']) - df['b2']) / ((0.1 * df['b8_a']) + df['b2'])

def NDVI1(df):
    return (df['b8'] - df['b4']) / (df['b8'] + df['b4'])

def NDVI2(df):
    return (df['b8_a'] - df['b4']) / (df['b8_a'] + df['b4'])

def WDRVI1(df):
    return ((0.1 * df['b8']) - df['b4']) / ((0.1 * df['b8']) + df['b4'])

def WDRVI2(df):
    return ((0.1 * df['b8_a']) - df['b4']) / ((0.1 * df['b8_a']) + df['b4'])

def SAVI1(df):
    return ((1 + 0.5) * (df['b8'] - df['b4'])) / (df['b8'] + df['b4'] + 0.5)

def SAVI2(df):
    return ((1 + 0.5) * (df['b8_a'] - df['b4'])) / (df['b8_a'] + df['b4'] + 0.5)

def GNDVI1(df):
    return (df['b8'] - df['b3']) / (df['b8'] + df['b3'])

def GNDVI2(df):
    return (df['b8_a'] - df['b3']) / (df['b8_a'] + df['b3'])

def NDRE1(df):
    return (df['b8'] - df['b5']) / (df['b8'] + df['b5'])

def NDRE2(df):
    return (df['b8'] - df['b6']) / (df['b8'] + df['b6'])

def NDRE3(df):
    return (df['b8'] - df['b7']) / (df['b8'] + df['b7'])

def NDRE4(df):
    return (df['b8_a'] - df['b5']) / (df['b8_a'] + df['b5'])

def NDRE5(df):
    return (df['b8_a'] - df['b6']) / (df['b8_a'] + df['b6'])

def NDRE6(df):
    return (df['b8_a'] - df['b7']) / (df['b8_a'] + df['b7'])

def VIgreen(df):
    return (df['b3'] - df['b4']) / (df['b3'] + df['b4'])

def CIgreen1(df):
    return (df['b8'] / df['b3']) - 1

def CIgreen2(df):
    return (df['b8_a'] / df['b3']) - 1

def CIrededge1(df):
    return (df['b8'] / df['b5']) - 1

def CIrededge2(df):
    return (df['b8'] / df['b6']) - 1

def CIrededge3(df):
    return (df['b8'] / df['b7']) - 1

def CIrededge4(df):
    return (df['b8_a'] / df['b5']) - 1

def CIrededge5(df):
    return (df['b8_a'] / df['b6']) - 1

def CIrededge6(df):
    return (df['b8_a'] / df['b7']) - 1

def CI(df):
    return (df['b4'] - df['b2']) / df['b4']

def CVI1(df):
    return df['b8'] * (df['b4'] / (df['b3']^2))

def CVI2(df):
    return df['b8_a'] * (df['b4'] / (df['b3']^2))

def CCCI1(df):
    return ((df['b8'] - df['b5']) / (df['b8'] + df['b5'])) / ((df['b8'] - df['b4']) / (df['b8'] + df['b4']))

def CCCI2(df):
    return ((df['b8'] - df['b6']) / (df['b8'] + df['b6'])) / ((df['b8'] - df['b4']) / (df['b8'] + df['b4']))

def CCCI3(df):
    return ((df['b8'] - df['b7']) / (df['b8'] + df['b7'])) / ((df['b8'] - df['b4']) / (df['b8'] + df['b4']))

def CCCI4(df):
    return ((df['b8_a'] - df['b5']) / (df['b8_a'] + df['b5'])) / ((df['b8_a'] - df['b4']) / (df['b8_a'] + df['b4']))

def CCCI5(df):
    return ((df['b8_a'] - df['b6']) / (df['b8_a'] + df['b6'])) / ((df['b8_a'] - df['b4']) / (df['b8_a'] + df['b4']))

def CCCI6(df):
    return ((df['b8_a'] - df['b7']) / (df['b8_a'] + df['b7'])) / ((df['b8_a'] - df['b4']) / (df['b8_a'] + df['b4']))

def EVI1(df):
    return 2.5 * ((df['b8'] - df['b4']) / (df['b8'] + (6 * df['b4']) - (7.5 * df['b2']) + 1))

def EVI2(df):
    return 2.5 * ((df['b8_a'] - df['b4']) / (df['b8_a'] + (6 * df['b4']) - (7.5 * df['b2']) + 1))

def GARI1(df):
    return (df['b8'] - (df['b3'] - (df['b2'] - df['b4']))) / (df['b8'] - (df['b3'] + (df['b2'] - df['b4'])))

def GARI2(df):
    return (df['b8_a'] - (df['b3'] - (df['b2'] - df['b4']))) / (df['b8_a'] - (df['b3'] + (df['b2'] - df['b4'])))

def GLI(df):
    return ((2 * df['b3']) - (df['b4'] + df['b2'])) / ((2 * df['b3']) + (df['b4'] + df['b2']))

def GBNDVI1(df):
    return (df['b8'] - (df['b3'] + df['b2'])) / (df['b8'] + (df['b3'] + df['b2']))

def GBNDVI1(df):
    return (df['b8_a'] - (df['b3'] + df['b2'])) / (df['b8_a'] + (df['b3'] + df['b2']))

def GRNDVI1(df):
    return (df['b8'] - (df['b3'] + df['b4'])) / (df['b8'] + (df['b3'] + df['b4']))

def GRNDVI2(df):
    return (df['b8_a'] - (df['b3'] + df['b4'])) / (df['b8_a'] + (df['b3'] + df['b4']))

def SLAVI1(df):
    return df['b8'] / (df['b4'] + df['b11'])

def SLAVI2(df):
    return df['b8_a'] / (df['b4'] + df['b11'])

def SLAVI3(df):
    return df['b8'] / (df['b4'] + df['b12'])

def SLAVI4(df):
    return df['b8_a'] / (df['b4'] + df['b12'])

# %%
# List of function names and function references
functions_name_list = [
    "NDWI", "NDSI", "BSI", 
    "NBR1", "NBR3", "NBR4", 
    "AFRI1", "AFRI2", "AFRI3", "AFRI4", 
    "BNDVI1", "BNDVI2", "BWDRVI1", "BWDRVI2", 
    "NDVI1", "NDVI2", "WDRVI1", "WDRVI2", "SAVI1", "SAVI2", "GNDVI1", 
    "GNDVI2", 
    "NDRE1", "NDRE2", "NDRE3", "NDRE4", "NDRE5", "NDRE6", "VIgreen", "CIgreen1", 
    "CIgreen2", "CIrededge1", "CIrededge2", "CIrededge3", "CIrededge4", "CIrededge5", 
    "CIrededge6", "CI", "CVI1", "CVI2", "CCCI1", "CCCI2", "CCCI3", "CCCI4", 
    "CCCI5", "CCCI6", "EVI1", "EVI2", "GARI1", "GARI2", 
    "GLI", "GBNDVI1", 
    "GBNDVI1", "GRNDVI1", "GRNDVI2", "SLAVI1", "SLAVI2", "SLAVI3", "SLAVI4"
]

functions_list = [
    NDWI, NDSI, BSI, 
    NBR1, NBR3, NBR4, 
    AFRI1, AFRI2, AFRI3, AFRI4, 
    BNDVI1, BNDVI2, BWDRVI1, BWDRVI2, 
    NDVI1, NDVI2, WDRVI1, WDRVI2, SAVI1, SAVI2, GNDVI1, 
    GNDVI2, 
    NDRE1, NDRE2, NDRE3, NDRE4, NDRE5, NDRE6, VIgreen, CIgreen1, 
    CIgreen2, CIrededge1, CIrededge2, CIrededge3, CIrededge4, CIrededge5, 
    CIrededge6, CI, CVI1, CVI2, CCCI1, CCCI2, CCCI3, CCCI4, 
    CCCI5, CCCI6, EVI1, EVI2, GARI1, GARI2, 
    GLI, GBNDVI1, 
    GBNDVI1, GRNDVI1, GRNDVI2, SLAVI1, SLAVI2, SLAVI3, SLAVI4
]

# Perform feature engineering
train_featureEng = train.copy()
for i, func in enumerate(functions_list):
    train_featureEng[functions_name_list[i]] = func(train_featureEng)

# %%
# Prepare data for training
X = train_featureEng.drop('nforest_type', axis=1)
y = train_featureEng['nforest_type']

# Encode target labels if necessary
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=40)

# %%
# Define the objective function for Optuna
def objective(trial):
    params = {
        'objective': 'multi:softmax',
        'num_class': 3,  # Number of classes
        'booster': 'gbtree',
        # 'lambda': trial.suggest_loguniform('lambda', 1e-3, 10.0),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'alpha': trial.suggest_float('alpha', 1e-3, 10.0),
        'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.1),
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        # 'gamma': trial.suggest_loguniform('gamma', 1e-3, 10.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'grow_policy': trial.suggest_categorical('grow_policy', ['depthwise', 'lossguide'])
    }
    xgb_clf = XGBClassifier(**params)
    
    # Cross-validation
    cv_scores = cross_val_score(xgb_clf, X_train, y_train, cv=3, scoring='accuracy')
    
    return np.mean(cv_scores)

# %%
"""
Accuracy: 0.71
Best hyperparameters: {'max_depth': 10, 
                       'alpha': 2.4693579223725726, 
                       'learning_rate': 0.04105650186992039, 
                       'n_estimators': 478, 
                       'subsample': 0.8487446825233986, 
                       'colsample_bytree': 0.9498799391621067}
"""

# %%
# Create the Optuna study and optimize
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

# Get the best hyperparameters
best_params = study.best_params

# Train the final model with the best hyperparameters
xgb_clf = XGBClassifier(**best_params)
xgb_clf.fit(X_train, y_train)

# Make predictions on the test set
y_pred = xgb_clf.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')
print('Best hyperparameters:', best_params)
# Out:
# [I 2024-06-06 02:46:01,323] A new study created in memory with name: no-name-9acfa3e7-bb4f-4f90-9500-4092410ec0a5
# [I 2024-06-06 02:46:21,839] Trial 0 finished with value: 0.6773614234250299 and parameters: {'max_depth': 5, 'alpha': 6.349277526713798, 'learning_rate': 0.038814153258011366, 'n_estimators': 543, 'subsample': 0.8259102949972708, 'colsample_bytree': 0.6280710894270878, 'grow_policy': 'lossguide'}. Best is trial 0 with value: 0.6773614234250299.
# [I 2024-06-06 02:46:45,170] Trial 1 finished with value: 0.6805217926323633 and parameters: {'max_depth': 7, 'alpha': 3.061296118411001, 'learning_rate': 0.09618859944610933, 'n_estimators': 559, 'subsample': 0.6030658064829355, 'colsample_bytree': 0.8188016201230148, 'grow_policy': 'depthwise'}. Best is trial 1 with value: 0.6805217926323633.
# [I 2024-06-06 02:46:54,618] Trial 2 finished with value: 0.6432679702952316 and parameters: {'max_depth': 3, 'alpha': 8.780353559629228, 'learning_rate': 0.005155805350868427, 'n_estimators': 739, 'subsample': 0.8874924361417212, 'colsample_bytree': 0.796820420262121, 'grow_policy': 'depthwise'}. Best is trial 1 with value: 0.6805217926323633.
# [I 2024-06-06 02:49:19,892] Trial 3 finished with value: 0.6846395759795101 and parameters: {'max_depth': 10, 'alpha': 0.405653493993909, 'learning_rate': 0.07649187392204719, 'n_estimators': 940, 'subsample': 0.8485339834816288, 'colsample_bytree': 0.8767940180529037, 'grow_policy': 'lossguide'}. Best is trial 3 with value: 0.6846395759795101.
# [I 2024-06-06 02:49:44,902] Trial 4 finished with value: 0.6803305794675198 and parameters: {'max_depth': 6, 'alpha': 2.337414851128392, 'learning_rate': 0.01292315761044785, 'n_estimators': 766, 'subsample': 0.8926669586239477, 'colsample_bytree': 0.595456385989229, 'grow_policy': 'depthwise'}. Best is trial 3 with value: 0.6846395759795101.
# [I 2024-06-06 02:49:58,625] Trial 5 finished with value: 0.6752551068141118 and parameters: {'max_depth': 3, 'alpha': 3.4465333166858567, 'learning_rate': 0.08588211130540319, 'n_estimators': 927, 'subsample': 0.8012575139366822, 'colsample_bytree': 0.6233669378849674, 'grow_policy': 'lossguide'}. Best is trial 3 with value: 0.6846395759795101.
# [I 2024-06-06 02:51:25,614] Trial 6 finished with value: 0.6878958957273255 and parameters: {'max_depth': 9, 'alpha': 1.5750096109903882, 'learning_rate': 0.028937864733195318, 'n_estimators': 962, 'subsample': 0.8702203462433624, 'colsample_bytree': 0.8635059135525637, 'grow_policy': 'depthwise'}. Best is trial 6 with value: 0.6878958957273255.
# [I 2024-06-06 02:52:10,712] Trial 7 finished with value: 0.6798517072977445 and parameters: {'max_depth': 7, 'alpha': 3.751862942386504, 'learning_rate': 0.02532654191626661, 'n_estimators': 470, 'subsample': 0.5154622214588241, 'colsample_bytree': 0.6876434580677656, 'grow_policy': 'lossguide'}. Best is trial 6 with value: 0.6878958957273255.
# [I 2024-06-06 02:52:20,934] Trial 8 finished with value: 0.6384793861807007 and parameters: {'max_depth': 3, 'alpha': 6.030888947968436, 'learning_rate': 0.003922871476593903, 'n_estimators': 739, 'subsample': 0.5471808254505606, 'colsample_bytree': 0.8936149366796378, 'grow_policy': 'depthwise'}. Best is trial 6 with value: 0.6878958957273255.
# [I 2024-06-06 02:53:40,352] Trial 9 finished with value: 0.6781275968833548 and parameters: {'max_depth': 8, 'alpha': 2.1713641688815652, 'learning_rate': 0.07380725984640533, 'n_estimators': 761, 'subsample': 0.686504629950318, 'colsample_bytree': 0.6050570328347422, 'grow_policy': 'lossguide'}. Best is trial 6 with value: 0.6878958957273255.
# [I 2024-06-06 02:54:08,569] Trial 10 finished with value: 0.6851186407657992 and parameters: {'max_depth': 10, 'alpha': 0.5272067543940508, 'learning_rate': 0.053796558217683026, 'n_estimators': 202, 'subsample': 0.7085625048159994, 'colsample_bytree': 0.9657698921376426, 'grow_policy': 'depthwise'}. Best is trial 6 with value: 0.6878958957273255.
# [I 2024-06-06 02:54:27,563] Trial 11 finished with value: 0.6824370611783067 and parameters: {'max_depth': 10, 'alpha': 0.07745412170776911, 'learning_rate': 0.05540301348084695, 'n_estimators': 133, 'subsample': 0.9913879202281874, 'colsample_bytree': 0.9891877568363281, 'grow_policy': 'depthwise'}. Best is trial 6 with value: 0.6878958957273255.
# [I 2024-06-06 02:54:43,324] Trial 12 finished with value: 0.6858848142241242 and parameters: {'max_depth': 9, 'alpha': 1.3388029536208448, 'learning_rate': 0.05206205150265176, 'n_estimators': 135, 'subsample': 0.697407615252831, 'colsample_bytree': 0.9939961085009543, 'grow_policy': 'depthwise'}. Best is trial 6 with value: 0.6878958957273255.
# [I 2024-06-06 02:55:16,797] Trial 13 finished with value: 0.6863638514937686 and parameters: {'max_depth': 9, 'alpha': 1.4774897658239632, 'learning_rate': 0.036989245916518323, 'n_estimators': 318, 'subsample': 0.6585569051184045, 'colsample_bytree': 0.9111787946643113, 'grow_policy': 'depthwise'}. Best is trial 6 with value: 0.6878958957273255.
# [I 2024-06-06 02:55:40,320] Trial 14 finished with value: 0.6812883513237157 and parameters: {'max_depth': 8, 'alpha': 5.109233145937395, 'learning_rate': 0.030944456798898005, 'n_estimators': 343, 'subsample': 0.9409149860836625, 'colsample_bytree': 0.893053167770427, 'grow_policy': 'depthwise'}. Best is trial 6 with value: 0.6878958957273255.
# [I 2024-06-06 02:55:58,255] Trial 15 finished with value: 0.6737227323808171 and parameters: {'max_depth': 9, 'alpha': 9.849721357541664, 'learning_rate': 0.034237090872527604, 'n_estimators': 340, 'subsample': 0.6309578083047285, 'colsample_bytree': 0.5100136236558983, 'grow_policy': 'depthwise'}. Best is trial 6 with value: 0.6878958957273255.
# [I 2024-06-06 02:56:22,353] Trial 16 finished with value: 0.6810009399685869 and parameters: {'max_depth': 8, 'alpha': 4.470494000582689, 'learning_rate': 0.019397975979048115, 'n_estimators': 340, 'subsample': 0.7438958340517643, 'colsample_bytree': 0.7482868908679113, 'grow_policy': 'depthwise'}. Best is trial 6 with value: 0.6878958957273255.
# [I 2024-06-06 02:56:38,002] Trial 17 finished with value: 0.6832033171865661 and parameters: {'max_depth': 5, 'alpha': 1.7327881111559384, 'learning_rate': 0.04090486458748542, 'n_estimators': 608, 'subsample': 0.7833953664135866, 'colsample_bytree': 0.8335236860688049, 'grow_policy': 'depthwise'}. Best is trial 6 with value: 0.6878958957273255.
# [I 2024-06-06 02:57:03,865] Trial 18 finished with value: 0.6852144262064123 and parameters: {'max_depth': 9, 'alpha': 7.055534047489364, 'learning_rate': 0.06511725067339597, 'n_estimators': 428, 'subsample': 0.6396000911340869, 'colsample_bytree': 0.9312779967288637, 'grow_policy': 'depthwise'}. Best is trial 6 with value: 0.6878958957273255.
# [I 2024-06-06 02:57:13,332] Trial 19 finished with value: 0.6837783600299822 and parameters: {'max_depth': 6, 'alpha': 1.4384817169498247, 'learning_rate': 0.04554482979402284, 'n_estimators': 250, 'subsample': 0.5745223068352636, 'colsample_bytree': 0.7451627036998292, 'grow_policy': 'depthwise'}. Best is trial 6 with value: 0.6878958957273255.
# [I 2024-06-06 02:58:45,708] Trial 20 finished with value: 0.6880875216418412 and parameters: {'max_depth': 9, 'alpha': 2.6071340663256923, 'learning_rate': 0.018345996728446903, 'n_estimators': 989, 'subsample': 0.7638226256261683, 'colsample_bytree': 0.8553368549776346, 'grow_policy': 'depthwise'}. Best is trial 20 with value: 0.6880875216418412.
# [I 2024-06-06 03:00:15,971] Trial 21 finished with value: 0.6889492328909758 and parameters: {'max_depth': 9, 'alpha': 2.752982933806547, 'learning_rate': 0.018966524662341975, 'n_estimators': 999, 'subsample': 0.7841420652099196, 'colsample_bytree': 0.8619164625590591, 'grow_policy': 'depthwise'}. Best is trial 21 with value: 0.6889492328909758.
# [I 2024-06-06 03:01:26,180] Trial 22 finished with value: 0.6884705258210692 and parameters: {'max_depth': 8, 'alpha': 2.9903382408096237, 'learning_rate': 0.01647975058049211, 'n_estimators': 973, 'subsample': 0.7520944987570727, 'colsample_bytree': 0.8464664361376615, 'grow_policy': 'depthwise'}. Best is trial 21 with value: 0.6889492328909758.
# [I 2024-06-06 03:02:24,600] Trial 23 finished with value: 0.6855975954855092 and parameters: {'max_depth': 8, 'alpha': 4.188907813204336, 'learning_rate': 0.01652563670860532, 'n_estimators': 858, 'subsample': 0.7507851058220272, 'colsample_bytree': 0.7978564077156721, 'grow_policy': 'depthwise'}. Best is trial 21 with value: 0.6889492328909758.
# [I 2024-06-06 03:03:30,794] Trial 24 finished with value: 0.6860767703383776 and parameters: {'max_depth': 8, 'alpha': 2.8704036952556278, 'learning_rate': 0.012899796416220327, 'n_estimators': 855, 'subsample': 0.7794077424276714, 'colsample_bytree': 0.8538974543887508, 'grow_policy': 'depthwise'}. Best is trial 21 with value: 0.6889492328909758.
# [I 2024-06-06 03:04:16,393] Trial 25 finished with value: 0.6846396310127997 and parameters: {'max_depth': 7, 'alpha': 5.26657640373576, 'learning_rate': 0.022385939346816916, 'n_estimators': 1000, 'subsample': 0.7425426587055977, 'colsample_bytree': 0.940337974908361, 'grow_policy': 'depthwise'}. Best is trial 21 with value: 0.6889492328909758.
# [I 2024-06-06 03:08:22,569] Trial 26 finished with value: 0.6842570946165335 and parameters: {'max_depth': 10, 'alpha': 2.6471448381772, 'learning_rate': 0.00877686406904564, 'n_estimators': 850, 'subsample': 0.8143528873102153, 'colsample_bytree': 0.7811462944937257, 'grow_policy': 'lossguide'}. Best is trial 21 with value: 0.6889492328909758.
# [I 2024-06-06 03:09:28,801] Trial 27 finished with value: 0.685597182735837 and parameters: {'max_depth': 9, 'alpha': 4.103995067667768, 'learning_rate': 0.02661869412273003, 'n_estimators': 891, 'subsample': 0.7281967128074593, 'colsample_bytree': 0.6952762442604692, 'grow_policy': 'depthwise'}. Best is trial 21 with value: 0.6889492328909758.
# [I 2024-06-06 03:10:03,594] Trial 28 finished with value: 0.6651032809746615 and parameters: {'max_depth': 7, 'alpha': 3.309229403193984, 'learning_rate': 0.001807690819659976, 'n_estimators': 662, 'subsample': 0.7703530554847645, 'colsample_bytree': 0.8353244371321094, 'grow_policy': 'depthwise'}. Best is trial 21 with value: 0.6889492328909758.
# [I 2024-06-06 03:11:29,038] Trial 29 finished with value: 0.6820543596821717 and parameters: {'max_depth': 8, 'alpha': 7.297542409152582, 'learning_rate': 0.041878495620590046, 'n_estimators': 1000, 'subsample': 0.8338236728042946, 'colsample_bytree': 0.7216502020386749, 'grow_policy': 'lossguide'}. Best is trial 21 with value: 0.6889492328909758.
# [I 2024-06-06 03:11:50,043] Trial 30 finished with value: 0.6791813192800324 and parameters: {'max_depth': 5, 'alpha': 5.827006854032489, 'learning_rate': 0.015674336007527514, 'n_estimators': 813, 'subsample': 0.6732333698741193, 'colsample_bytree': 0.9374798973243326, 'grow_policy': 'depthwise'}. Best is trial 21 with value: 0.6889492328909758.
# [I 2024-06-06 03:13:20,068] Trial 31 finished with value: 0.6851189709655371 and parameters: {'max_depth': 9, 'alpha': 0.8220258568485115, 'learning_rate': 0.027037200147908447, 'n_estimators': 945, 'subsample': 0.8699211470737914, 'colsample_bytree': 0.8613349333807897, 'grow_policy': 'depthwise'}. Best is trial 21 with value: 0.6889492328909758.
# [I 2024-06-06 03:14:48,102] Trial 32 finished with value: 0.6846398511459583 and parameters: {'max_depth': 9, 'alpha': 2.077844202304642, 'learning_rate': 0.020842216412170673, 'n_estimators': 957, 'subsample': 0.8436969957972684, 'colsample_bytree': 0.7833418851200618, 'grow_policy': 'depthwise'}. Best is trial 21 with value: 0.6889492328909758.
# [I 2024-06-06 03:16:44,204] Trial 33 finished with value: 0.685406189704152 and parameters: {'max_depth': 10, 'alpha': 3.068044675861174, 'learning_rate': 0.009201076416584875, 'n_estimators': 892, 'subsample': 0.8898928281797398, 'colsample_bytree': 0.8246641579162196, 'grow_policy': 'depthwise'}. Best is trial 21 with value: 0.6889492328909758.
# [I 2024-06-06 03:18:16,040] Trial 34 finished with value: 0.686267845919997 and parameters: {'max_depth': 9, 'alpha': 0.9873623032400207, 'learning_rate': 0.03021174808840235, 'n_estimators': 999, 'subsample': 0.9436113456782129, 'colsample_bytree': 0.8609923480157518, 'grow_policy': 'depthwise'}. Best is trial 21 with value: 0.6889492328909758.
# [I 2024-06-06 03:19:08,394] Trial 35 finished with value: 0.6833951907508852 and parameters: {'max_depth': 8, 'alpha': 2.507945269884751, 'learning_rate': 0.010774289715596585, 'n_estimators': 666, 'subsample': 0.9237404833521468, 'colsample_bytree': 0.811696962227421, 'grow_policy': 'depthwise'}. Best is trial 21 with value: 0.6889492328909758.
# [I 2024-06-06 03:20:51,540] Trial 36 finished with value: 0.6878961433771288 and parameters: {'max_depth': 10, 'alpha': 1.9707342631685185, 'learning_rate': 0.018699129872031445, 'n_estimators': 816, 'subsample': 0.8162988967938799, 'colsample_bytree': 0.8973554719625654, 'grow_policy': 'depthwise'}. Best is trial 21 with value: 0.6889492328909758.
# [I 2024-06-06 03:22:21,080] Trial 37 finished with value: 0.6844481977147977 and parameters: {'max_depth': 10, 'alpha': 3.6139253965136757, 'learning_rate': 0.09715372659359856, 'n_estimators': 926, 'subsample': 0.8010625690900802, 'colsample_bytree': 0.9051357251798016, 'grow_policy': 'lossguide'}. Best is trial 21 with value: 0.6889492328909758.
# [I 2024-06-06 03:22:35,862] Trial 38 finished with value: 0.6644324251739878 and parameters: {'max_depth': 4, 'alpha': 2.2333452439275514, 'learning_rate': 0.006471945782755754, 'n_estimators': 788, 'subsample': 0.720135335270689, 'colsample_bytree': 0.9538578205296973, 'grow_policy': 'depthwise'}. Best is trial 21 with value: 0.6889492328909758.
# [I 2024-06-06 03:23:51,164] Trial 39 finished with value: 0.6864598295508954 and parameters: {'max_depth': 10, 'alpha': 4.660462254386723, 'learning_rate': 0.022187553423521723, 'n_estimators': 812, 'subsample': 0.7628418475447903, 'colsample_bytree': 0.889172151352014, 'grow_policy': 'depthwise'}. Best is trial 21 with value: 0.6889492328909758.
# [I 2024-06-06 03:25:05,063] Trial 40 finished with value: 0.6847356365865712 and parameters: {'max_depth': 7, 'alpha': 3.8682363285136527, 'learning_rate': 0.016078043235173547, 'n_estimators': 697, 'subsample': 0.8106021362738831, 'colsample_bytree': 0.8438144641586547, 'grow_policy': 'lossguide'}. Best is trial 21 with value: 0.6889492328909758.
# [I 2024-06-06 03:26:22,660] Trial 41 finished with value: 0.6855974303856404 and parameters: {'max_depth': 9, 'alpha': 1.93689922303437, 'learning_rate': 0.03405578521866344, 'n_estimators': 905, 'subsample': 0.8568371250782835, 'colsample_bytree': 0.8658043761181533, 'grow_policy': 'depthwise'}. Best is trial 21 with value: 0.6889492328909758.
# [I 2024-06-06 03:27:58,398] Trial 42 finished with value: 0.685214481239702 and parameters: {'max_depth': 10, 'alpha': 2.9746718020366383, 'learning_rate': 0.025577244156319734, 'n_estimators': 956, 'subsample': 0.8278849837929819, 'colsample_bytree': 0.9189653836166951, 'grow_policy': 'depthwise'}. Best is trial 21 with value: 0.6889492328909758.
# [I 2024-06-06 03:29:59,126] Trial 43 finished with value: 0.6888537501334557 and parameters: {'max_depth': 10, 'alpha': 0.8924421818556914, 'learning_rate': 0.01742242107557919, 'n_estimators': 953, 'subsample': 0.7889158976022855, 'colsample_bytree': 0.8783760296592231, 'grow_policy': 'depthwise'}. Best is trial 21 with value: 0.6889492328909758.
# [I 2024-06-06 03:32:32,443] Trial 44 finished with value: 0.6814793718720454 and parameters: {'max_depth': 10, 'alpha': 0.0832941154174971, 'learning_rate': 0.0013018725488766862, 'n_estimators': 877, 'subsample': 0.7910104195473421, 'colsample_bytree': 0.883670489611256, 'grow_policy': 'depthwise'}. Best is trial 21 with value: 0.6889492328909758.
# [I 2024-06-06 03:33:34,001] Trial 45 finished with value: 0.6825332593685921 and parameters: {'max_depth': 10, 'alpha': 1.0175473509894575, 'learning_rate': 0.08949268525698434, 'n_estimators': 924, 'subsample': 0.7198409536501892, 'colsample_bytree': 0.7706255558279699, 'grow_policy': 'depthwise'}. Best is trial 21 with value: 0.6889492328909758.
# [I 2024-06-06 03:35:16,789] Trial 46 finished with value: 0.6889493429575552 and parameters: {'max_depth': 9, 'alpha': 0.5491924538727071, 'learning_rate': 0.016971225502532297, 'n_estimators': 972, 'subsample': 0.7647460118192174, 'colsample_bytree': 0.9735010505990359, 'grow_policy': 'depthwise'}. Best is trial 46 with value: 0.6889493429575552.
# [I 2024-06-06 03:36:55,459] Trial 47 finished with value: 0.6886622342855193 and parameters: {'max_depth': 9, 'alpha': 0.4303052063750326, 'learning_rate': 0.01334871144860713, 'n_estimators': 965, 'subsample': 0.6851999650884724, 'colsample_bytree': 0.9798539860812789, 'grow_policy': 'depthwise'}. Best is trial 46 with value: 0.6889493429575552.
# [I 2024-06-06 03:38:27,876] Trial 48 finished with value: 0.6798514046146513 and parameters: {'max_depth': 8, 'alpha': 0.6411571182158184, 'learning_rate': 0.0060685740280018545, 'n_estimators': 502, 'subsample': 0.6916703685690764, 'colsample_bytree': 0.970952223038182, 'grow_policy': 'lossguide'}. Best is trial 46 with value: 0.6889493429575552.
# [I 2024-06-06 03:39:40,923] Trial 49 finished with value: 0.6871297497856453 and parameters: {'max_depth': 9, 'alpha': 0.05091783373463166, 'learning_rate': 0.012961398735993687, 'n_estimators': 738, 'subsample': 0.6739474537209593, 'colsample_bytree': 0.975630783082094, 'grow_policy': 'depthwise'}. Best is trial 46 with value: 0.6889493429575552.
# [I 2024-06-06 03:40:54,074] Trial 50 finished with value: 0.6865553398250602 and parameters: {'max_depth': 8, 'alpha': 1.0480280526938863, 'learning_rate': 0.02367774035849831, 'n_estimators': 956, 'subsample': 0.603927955829312, 'colsample_bytree': 0.9932444545065684, 'grow_policy': 'depthwise'}. Best is trial 46 with value: 0.6889493429575552.
# [I 2024-06-06 03:42:36,599] Trial 51 finished with value: 0.6909605895606252 and parameters: {'max_depth': 9, 'alpha': 0.4683674661936345, 'learning_rate': 0.012906764390309008, 'n_estimators': 977, 'subsample': 0.7599833624472752, 'colsample_bytree': 0.9592127445770873, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 03:44:11,492] Trial 52 finished with value: 0.6883748779636804 and parameters: {'max_depth': 9, 'alpha': 0.39991351892677596, 'learning_rate': 0.012869126339304095, 'n_estimators': 918, 'subsample': 0.7378420035743603, 'colsample_bytree': 0.9514704785732291, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 03:45:57,807] Trial 53 finished with value: 0.6847361318861779 and parameters: {'max_depth': 9, 'alpha': 0.5296130964961098, 'learning_rate': 0.0062531785113751105, 'n_estimators': 971, 'subsample': 0.7040780071664218, 'colsample_bytree': 0.9222130608886925, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 03:47:05,486] Trial 54 finished with value: 0.6828200928741796 and parameters: {'max_depth': 8, 'alpha': 1.2808365610074266, 'learning_rate': 0.03189798710716554, 'n_estimators': 926, 'subsample': 0.7543232002455406, 'colsample_bytree': 0.9552574295659991, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 03:48:37,271] Trial 55 finished with value: 0.6863638790104134 and parameters: {'max_depth': 9, 'alpha': 1.6497879102601976, 'learning_rate': 0.013796516456545616, 'n_estimators': 851, 'subsample': 0.7870478225887284, 'colsample_bytree': 0.9795577234798465, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 03:49:13,091] Trial 56 finished with value: 0.6881831144659404 and parameters: {'max_depth': 6, 'alpha': 0.31806127625225034, 'learning_rate': 0.01992906440360764, 'n_estimators': 967, 'subsample': 0.6298181017738602, 'colsample_bytree': 0.9972496482918314, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 03:51:18,665] Trial 57 finished with value: 0.6876087870552897 and parameters: {'max_depth': 10, 'alpha': 1.243874559789106, 'learning_rate': 0.009320371830069639, 'n_estimators': 873, 'subsample': 0.7728593035111838, 'colsample_bytree': 0.9145636402366921, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 03:52:34,779] Trial 58 finished with value: 0.6861721155126737 and parameters: {'max_depth': 9, 'alpha': 0.5663279149237175, 'learning_rate': 0.04693286250614876, 'n_estimators': 902, 'subsample': 0.6573467151056891, 'colsample_bytree': 0.963597640927362, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 03:53:29,910] Trial 59 finished with value: 0.688374905480325 and parameters: {'max_depth': 7, 'alpha': 1.6714001277495, 'learning_rate': 0.016772723743357212, 'n_estimators': 985, 'subsample': 0.7275205113989264, 'colsample_bytree': 0.9335574373702938, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 03:55:36,483] Trial 60 finished with value: 0.685980792281251 and parameters: {'max_depth': 8, 'alpha': 0.7342813863383029, 'learning_rate': 0.024226456067144183, 'n_estimators': 831, 'subsample': 0.5012426591438934, 'colsample_bytree': 0.6583837646481036, 'grow_policy': 'lossguide'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 03:56:11,114] Trial 61 finished with value: 0.6825331493020128 and parameters: {'max_depth': 6, 'alpha': 1.5598011980985298, 'learning_rate': 0.018085942769792772, 'n_estimators': 971, 'subsample': 0.7125985985665075, 'colsample_bytree': 0.552489276633077, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 03:57:08,740] Trial 62 finished with value: 0.6785109312623206 and parameters: {'max_depth': 7, 'alpha': 1.7299091826673145, 'learning_rate': 0.004456669535537961, 'n_estimators': 983, 'subsample': 0.7380998184306394, 'colsample_bytree': 0.9408176620439471, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 03:58:00,680] Trial 63 finished with value: 0.6885665589114857 and parameters: {'max_depth': 7, 'alpha': 1.1505457017350245, 'learning_rate': 0.015518908397504982, 'n_estimators': 938, 'subsample': 0.7997967509753435, 'colsample_bytree': 0.8810533111000959, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 03:58:59,915] Trial 64 finished with value: 0.6815753224125274 and parameters: {'max_depth': 8, 'alpha': 0.1710968366088293, 'learning_rate': 0.062065018188991836, 'n_estimators': 940, 'subsample': 0.8012698439123006, 'colsample_bytree': 0.8096838928837553, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 03:59:56,941] Trial 65 finished with value: 0.6852142060732538 and parameters: {'max_depth': 9, 'alpha': 1.1419740720890512, 'learning_rate': 0.03771193083290446, 'n_estimators': 566, 'subsample': 0.7567321465227037, 'colsample_bytree': 0.8756431448820056, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 04:01:05,746] Trial 66 finished with value: 0.6857892214000249 and parameters: {'max_depth': 8, 'alpha': 0.8328543635014722, 'learning_rate': 0.028960230067597546, 'n_estimators': 888, 'subsample': 0.780163119818127, 'colsample_bytree': 0.9809880388020851, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 04:02:44,766] Trial 67 finished with value: 0.6850230754583447 and parameters: {'max_depth': 9, 'alpha': 2.36278521524437, 'learning_rate': 0.01006905954873779, 'n_estimators': 932, 'subsample': 0.8381930150226304, 'colsample_bytree': 0.8785671650317695, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 04:03:04,618] Trial 68 finished with value: 0.6742971148247575 and parameters: {'max_depth': 7, 'alpha': 8.622566989039516, 'learning_rate': 0.014604182385356747, 'n_estimators': 418, 'subsample': 0.8625430287843224, 'colsample_bytree': 0.8410926378631094, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 04:04:32,083] Trial 69 finished with value: 0.6863635763273205 and parameters: {'max_depth': 9, 'alpha': 3.2939423296230266, 'learning_rate': 0.021552165424862865, 'n_estimators': 1000, 'subsample': 0.8021912439584541, 'colsample_bytree': 0.9045038358660296, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 04:05:21,883] Trial 70 finished with value: 0.6856930232097396 and parameters: {'max_depth': 8, 'alpha': 0.3949262424407683, 'learning_rate': 0.07232994851648647, 'n_estimators': 768, 'subsample': 0.768494773122149, 'colsample_bytree': 0.9281189087470894, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 04:06:16,427] Trial 71 finished with value: 0.687033854278453 and parameters: {'max_depth': 7, 'alpha': 1.315684267248109, 'learning_rate': 0.01707901533431884, 'n_estimators': 966, 'subsample': 0.7319121981952613, 'colsample_bytree': 0.945849625207492, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 04:06:51,525] Trial 72 finished with value: 0.6842570395832439 and parameters: {'max_depth': 6, 'alpha': 1.8924610028287954, 'learning_rate': 0.011224413727790539, 'n_estimators': 945, 'subsample': 0.7035339564650102, 'colsample_bytree': 0.9294945052180963, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 04:07:43,279] Trial 73 finished with value: 0.6867469107062862 and parameters: {'max_depth': 7, 'alpha': 0.8771259907198969, 'learning_rate': 0.015290400908740846, 'n_estimators': 903, 'subsample': 0.7508812057852982, 'colsample_bytree': 0.9660658821760446, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 04:08:36,075] Trial 74 finished with value: 0.6844480876482185 and parameters: {'max_depth': 7, 'alpha': 2.187809958475171, 'learning_rate': 0.02787326707583182, 'n_estimators': 980, 'subsample': 0.6808032931431577, 'colsample_bytree': 0.8774457986346509, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 04:09:46,518] Trial 75 finished with value: 0.6818629263841699 and parameters: {'max_depth': 8, 'alpha': 2.7656054635292824, 'learning_rate': 0.007682400515133782, 'n_estimators': 874, 'subsample': 0.7898274043640676, 'colsample_bytree': 0.9068040153763539, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 04:11:46,024] Trial 76 finished with value: 0.6868426411136097 and parameters: {'max_depth': 10, 'alpha': 1.445849749137196, 'learning_rate': 0.019303758471434066, 'n_estimators': 941, 'subsample': 0.8188992119958807, 'colsample_bytree': 0.9591773734654871, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 04:12:57,206] Trial 77 finished with value: 0.6784149532051938 and parameters: {'max_depth': 6, 'alpha': 0.653617335263238, 'learning_rate': 0.0036529344191671195, 'n_estimators': 983, 'subsample': 0.7252447014087099, 'colsample_bytree': 0.9308771690891722, 'grow_policy': 'lossguide'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 04:13:47,529] Trial 78 finished with value: 0.68521475640615 and parameters: {'max_depth': 7, 'alpha': 2.443957463011653, 'learning_rate': 0.012241595122907397, 'n_estimators': 912, 'subsample': 0.7642859326680661, 'colsample_bytree': 0.8241195061433028, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 04:15:10,967] Trial 79 finished with value: 0.6861721980626081 and parameters: {'max_depth': 9, 'alpha': 1.782812225931189, 'learning_rate': 0.023942254579349193, 'n_estimators': 834, 'subsample': 0.7468403777006449, 'colsample_bytree': 0.8967078101656971, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 04:15:35,332] Trial 80 finished with value: 0.6851186407657992 and parameters: {'max_depth': 5, 'alpha': 0.2629786765211084, 'learning_rate': 0.02111927314985858, 'n_estimators': 999, 'subsample': 0.6935191115452908, 'colsample_bytree': 0.8520134300130505, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 04:17:13,319] Trial 81 finished with value: 0.6877045724959028 and parameters: {'max_depth': 9, 'alpha': 0.4692833139167646, 'learning_rate': 0.014142781889338665, 'n_estimators': 916, 'subsample': 0.7349118686057114, 'colsample_bytree': 0.9843561703168261, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 04:18:53,859] Trial 82 finished with value: 0.6867466080231933 and parameters: {'max_depth': 9, 'alpha': 1.0505007275499108, 'learning_rate': 0.017421035281311, 'n_estimators': 950, 'subsample': 0.6605728186429707, 'colsample_bytree': 0.9388227634930568, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 04:20:07,796] Trial 83 finished with value: 0.6885664488449063 and parameters: {'max_depth': 8, 'alpha': 0.7575612238028473, 'learning_rate': 0.011488362067503515, 'n_estimators': 924, 'subsample': 0.775651746796156, 'colsample_bytree': 0.9154065839567771, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 04:21:26,526] Trial 84 finished with value: 0.6864596644510265 and parameters: {'max_depth': 8, 'alpha': 0.7827246652882994, 'learning_rate': 0.007860291949776157, 'n_estimators': 971, 'subsample': 0.7779820793328647, 'colsample_bytree': 0.9175727454788059, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 04:23:10,399] Trial 85 finished with value: 0.6748714697520531 and parameters: {'max_depth': 10, 'alpha': 5.474736391098749, 'learning_rate': 0.0029801597419843954, 'n_estimators': 886, 'subsample': 0.8016289274781749, 'colsample_bytree': 0.8694928231257538, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 04:23:55,426] Trial 86 finished with value: 0.68215011760614 and parameters: {'max_depth': 7, 'alpha': 6.733808967947447, 'learning_rate': 0.011660751710058676, 'n_estimators': 940, 'subsample': 0.717867352250183, 'colsample_bytree': 0.8901327693682408, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 04:25:16,517] Trial 87 finished with value: 0.6876089246385139 and parameters: {'max_depth': 8, 'alpha': 1.4497830007462318, 'learning_rate': 0.015413601082618269, 'n_estimators': 980, 'subsample': 0.8240940454825785, 'colsample_bytree': 0.9490692398129021, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 04:25:34,575] Trial 88 finished with value: 0.6824371162115964 and parameters: {'max_depth': 8, 'alpha': 1.1450614934473142, 'learning_rate': 0.025705224919468066, 'n_estimators': 219, 'subsample': 0.7624772911191725, 'colsample_bytree': 0.9994384581159327, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 04:25:36,597] Trial 89 finished with value: 0.6341698118191695 and parameters: {'max_depth': 3, 'alpha': 0.08276112716528716, 'learning_rate': 0.01916521768086417, 'n_estimators': 107, 'subsample': 0.8498942365825609, 'colsample_bytree': 0.9693229961853389, 'grow_policy': 'lossguide'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 04:27:03,644] Trial 90 finished with value: 0.6858847591908345 and parameters: {'max_depth': 10, 'alpha': 2.0777957771879407, 'learning_rate': 0.03265276394288385, 'n_estimators': 857, 'subsample': 0.788026927773295, 'colsample_bytree': 0.9094397536805774, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 04:28:39,664] Trial 91 finished with value: 0.6885665313948408 and parameters: {'max_depth': 9, 'alpha': 0.33333936344615045, 'learning_rate': 0.010839268716559746, 'n_estimators': 919, 'subsample': 0.7316440405064953, 'colsample_bytree': 0.9514781243768625, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 04:30:19,525] Trial 92 finished with value: 0.6859808197978957 and parameters: {'max_depth': 9, 'alpha': 0.2991970726102623, 'learning_rate': 0.010111706960193156, 'n_estimators': 959, 'subsample': 0.7477611090497338, 'colsample_bytree': 0.8507865748648574, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 04:32:07,706] Trial 93 finished with value: 0.6829164011310441 and parameters: {'max_depth': 9, 'alpha': 0.8715614559204055, 'learning_rate': 0.005614438940133961, 'n_estimators': 919, 'subsample': 0.7756791826822952, 'colsample_bytree': 0.9869889437255326, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 04:33:44,158] Trial 94 finished with value: 0.6883747954137457 and parameters: {'max_depth': 9, 'alpha': 0.5546418792649728, 'learning_rate': 0.01713462977613117, 'n_estimators': 903, 'subsample': 0.7070122063490837, 'colsample_bytree': 0.9591925351017081, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 04:34:59,189] Trial 95 finished with value: 0.6873218159664781 and parameters: {'max_depth': 8, 'alpha': 0.00871026433660832, 'learning_rate': 0.008244649997738931, 'n_estimators': 1000, 'subsample': 0.8100007440074926, 'colsample_bytree': 0.8971008734147563, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 04:35:16,171] Trial 96 finished with value: 0.6803305794675198 and parameters: {'max_depth': 4, 'alpha': 1.613942566144652, 'learning_rate': 0.022346731069445094, 'n_estimators': 933, 'subsample': 0.7407190106761533, 'colsample_bytree': 0.9222486893013402, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 04:37:29,064] Trial 97 finished with value: 0.6885665864281304 and parameters: {'max_depth': 10, 'alpha': 0.6444693497061478, 'learning_rate': 0.012684598138502097, 'n_estimators': 956, 'subsample': 0.7954603704087759, 'colsample_bytree': 0.9410413881002037, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 04:39:43,041] Trial 98 finished with value: 0.6884706634042933 and parameters: {'max_depth': 10, 'alpha': 0.7052592296265525, 'learning_rate': 0.012785268394517582, 'n_estimators': 954, 'subsample': 0.8322152283381445, 'colsample_bytree': 0.9447924938185635, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# [I 2024-06-06 04:41:47,643] Trial 99 finished with value: 0.6871301350186728 and parameters: {'max_depth': 10, 'alpha': 0.6655583146771212, 'learning_rate': 0.011706163592263022, 'n_estimators': 870, 'subsample': 0.7984575896524847, 'colsample_bytree': 0.9693411443750218, 'grow_policy': 'depthwise'}. Best is trial 51 with value: 0.6909605895606252.
# Number of completed trials: 100
# Accuracy: 0.71
# Best hyperparameters: {'max_depth': 9, 'alpha': 0.4683674661936345, 'learning_rate': 0.012906764390309008, 'n_estimators': 977, 'subsample': 0.7599833624472752, 'colsample_bytree': 0.9592127445770873, 'grow_policy': 'depthwise'}

# %%
best_params =  {'max_depth': 9, 
                'alpha': 0.4683674661936345, 
                'learning_rate': 0.012906764390309008, 
                'n_estimators': 977, 
                'subsample': 0.7599833624472752, 
                'colsample_bytree': 0.9592127445770873, 
                'grow_policy': 'depthwise'}

# Train the final model with the best hyperparameters
xgb_clf = XGBClassifier(**best_params)
xgb_clf.fit(X_train, y_train)
# Out:
# XGBClassifier(alpha=0.4683674661936345, base_score=None, booster=None,
#               callbacks=None, colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.9592127445770873, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=None,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints=None, learning_rate=0.012906764390309008,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=9, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=977, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
# Ensure the model has been fitted
if hasattr(xgb_clf, 'get_booster'):
    print("Model is fitted.")
else:
    print("Model is not fitted.")
# Out:
# Model is fitted.

# %%
"""
Accuracy: 0.71
Best hyperparameters: {'max_depth': 9, 
                       'alpha': 0.4683674661936345, 
                       'learning_rate': 0.012906764390309008, 
                       'n_estimators': 977, 
                       'subsample': 0.7599833624472752, 
                       'colsample_bytree': 0.9592127445770873, 
                       'grow_policy': 'depthwise'}
"""

# %%
# Load test dataset
test_df = pd.read_csv('test.csv')

# Apply feature engineering to the test set
test_featureEng = test_df.copy()
for i, func in enumerate(functions_list):
    test_featureEng[functions_name_list[i]] = func(test_featureEng)

# Make predictions on the test set
test_predictions = xgb_clf.predict(test_featureEng)

# Convert numeric predictions back to original string labels
test_predictions_labels = label_encoder.inverse_transform(test_predictions)

# Create a DataFrame for the predictions
output = pd.DataFrame({'id': test_df.index, 'nforest_type': test_predictions_labels})
output
# Out:
#         id nforest_type
# 0        0          DEF
# 1        1          MDF
# 2        2          MDF
# 3        3          DDF
# 4        4          MDF
# ...    ...          ...
# 3995  3995          DDF
# 3996  3996          MDF
# 3997  3997          DEF
# 3998  3998          MDF
# 3999  3999          DEF
#
# [4000 rows x 2 columns]

# %%
# Load sample submission file
sample_submission = pd.read_csv('/kaggle/input/forest-type-classification-spai/sample_submission.csv')

# Create submission DataFrame
submission = pd.DataFrame({'id': sample_submission['id'], 'nforest_type': test_predictions_labels})
submission

# # Save the submission DataFrame to a CSV file
submission.to_csv('feature(an)-hyperparameters-cv-2.csv', index=False)
submission
# Out:
#          id nforest_type
# 0     13467          DEF
# 1     12719          MDF
# 2      1054          MDF
# 3     13747          DDF
# 4      9453          MDF
# ...     ...          ...
# 3995    115          MDF
# 3996  10654          MDF
# 3997   5718          DEF
# 3998  13054          MDF
# 3999   6539          DEF
#
# [4000 rows x 2 columns]

# %%
# Load sample submission file
sample_submission = pd.read_csv('sample_submission.csv')

# Create submission DataFrame
submission = pd.DataFrame({'id': sample_submission['id'], 'nforest_type': test_predictions_labels})
submission

# # Save the submission DataFrame to a CSV file
submission.to_csv('feature(an)-hyperparameters-cv-2.csv', index=False)
submission
# Out:
#          id nforest_type
# 0     13467          DEF
# 1     12719          MDF
# 2      1054          MDF
# 3     13747          DDF
# 4      9453          MDF
# ...     ...          ...
# 3995    115          DDF
# 3996  10654          MDF
# 3997   5718          DEF
# 3998  13054          MDF
# 3999   6539          DEF
#
# [4000 rows x 2 columns]
