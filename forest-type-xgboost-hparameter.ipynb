# %%
import pandas as pd
import optuna
from xgboost import XGBClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Load training dataset
train = pd.read_csv('/kaggle/input/forest-type-classification-spai/train.csv')

# Features and target
X = train.drop('nforest_type', axis=1)
y = train['nforest_type']

# %%
# Encode target labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=40)

# Define the objective function for Optuna
def objective(trial):
    param = {
        'objective': 'multi:softmax',
        'num_class': 3,
        'max_depth': trial.suggest_int('max_depth', 3, 15),
        'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.3),
        'n_estimators': trial.suggest_int('n_estimators', 50, 400),
        'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
        'alpha': trial.suggest_loguniform('alpha', 1e-8, 10.0),
        'lambda': trial.suggest_loguniform('lambda', 1e-8, 10.0),
    }

    model = XGBClassifier(**param)
    model.fit(X_train, y_train)
    preds = model.predict(X_test)
    accuracy = accuracy_score(y_test, preds)
    
    return accuracy

# %%
# Create a study object and optimize the objective function
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=150)

# Print the best hyperparameters
print("Best hyperparameters: ", study.best_params)
# Out:
# [I 2024-06-03 13:42:07,118] A new study created in memory with name: no-name-1b62de6c-5ec3-4828-b227-7df1ccaa16da
# /tmp/ipykernel_33/3344094164.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.3),
# /tmp/ipykernel_33/3344094164.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_33/3344094164.py:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 10.0),
# /tmp/ipykernel_33/3344094164.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 10.0),
# [I 2024-06-03 13:42:08,396] Trial 0 finished with value: 0.6648793565683646 and parameters: {'max_depth': 15, 'learning_rate': 0.004563167694848605, 'n_estimators': 52, 'gamma': 1.4697287634363547e-07, 'min_child_weight': 10, 'subsample': 0.5322738270143645, 'colsample_bytree': 0.8025648630815294, 'alpha': 0.0012390461213570058, 'lambda': 6.0950422259769865e-05}. Best is trial 0 with value: 0.6648793565683646.
# /tmp/ipykernel_33/3344094164.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.3),
# /tmp/ipykernel_33/3344094164.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_33/3344094164.py:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 10.0),
# /tmp/ipykernel_33/3344094164.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 10.0),
# [I 2024-06-03 13:42:13,774] Trial 1 finished with value: 0.6943699731903485 and parameters: {'max_depth': 8, 'learning_rate': 0.03870289251782645, 'n_estimators': 378, 'gamma': 0.000852355383270989, 'min_child_weight': 3, 'subsample': 0.8659090274302, 'colsample_bytree': 0.8237110182613353, 'alpha': 0.00619600069356142, 'lambda': 1.5801103748173665e-07}. Best is trial 1 with value: 0.6943699731903485.
# /tmp/ipykernel_33/3344094164.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.3),
# /tmp/ipykernel_33/3344094164.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_33/3344094164.py:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 10.0),
# /tmp/ipykernel_33/3344094164.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 10.0),
# [I 2024-06-03 13:42:14,949] Trial 2 finished with value: 0.6216009191880506 and parameters: {'max_depth': 4, 'learning_rate': 0.008675932437773173, 'n_estimators': 196, 'gamma': 0.004656447444034416, 'min_child_weight': 3, 'subsample': 0.6377873257824765, 'colsample_bytree': 0.922179757224792, 'alpha': 1.4210755193398004, 'lambda': 7.723630577948173e-06}. Best is trial 1 with value: 0.6943699731903485.
# /tmp/ipykernel_33/3344094164.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.3),
# /tmp/ipykernel_33/3344094164.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_33/3344094164.py:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 10.0),
# /tmp/ipykernel_33/3344094164.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 10.0),
# [I 2024-06-03 13:42:26,156] Trial 3 finished with value: 0.6733052470317886 and parameters: {'max_depth': 11, 'learning_rate': 0.0043945909880516495, 'n_estimators': 279, 'gamma': 0.0001611193752394489, 'min_child_weight': 2, 'subsample': 0.7839659850588787, 'colsample_bytree': 0.5685723654822026, 'alpha': 5.339226825247008e-07, 'lambda': 1.2774875375225074e-06}. Best is trial 1 with value: 0.6943699731903485.
# /tmp/ipykernel_33/3344094164.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.3),
# /tmp/ipykernel_33/3344094164.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_33/3344094164.py:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 10.0),
# /tmp/ipykernel_33/3344094164.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 10.0),
# [I 2024-06-03 13:42:28,856] Trial 4 finished with value: 0.6717732669475297 and parameters: {'max_depth': 15, 'learning_rate': 0.0040711947363902025, 'n_estimators': 72, 'gamma': 0.01011154427336327, 'min_child_weight': 10, 'subsample': 0.9153077129393548, 'colsample_bytree': 0.8493066920872195, 'alpha': 0.000106281488774871, 'lambda': 0.0007611012832163067}. Best is trial 1 with value: 0.6943699731903485.
# /tmp/ipykernel_33/3344094164.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.3),
# /tmp/ipykernel_33/3344094164.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_33/3344094164.py:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 10.0),
# /tmp/ipykernel_33/3344094164.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 10.0),
# [I 2024-06-03 13:42:35,908] Trial 5 finished with value: 0.646112600536193 and parameters: {'max_depth': 14, 'learning_rate': 0.0017559898035290852, 'n_estimators': 390, 'gamma': 0.0012417115289510452, 'min_child_weight': 5, 'subsample': 0.5790372502261116, 'colsample_bytree': 0.8259454631309637, 'alpha': 5.696587518101681, 'lambda': 2.1586110106849392e-08}. Best is trial 1 with value: 0.6943699731903485.
# /tmp/ipykernel_33/3344094164.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.3),
# /tmp/ipykernel_33/3344094164.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_33/3344094164.py:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 10.0),
# /tmp/ipykernel_33/3344094164.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 10.0),
# [I 2024-06-03 13:42:44,335] Trial 6 finished with value: 0.6694752968211414 and parameters: {'max_depth': 12, 'learning_rate': 0.0014994462809271001, 'n_estimators': 215, 'gamma': 0.01291070516125435, 'min_child_weight': 3, 'subsample': 0.6470452103426747, 'colsample_bytree': 0.7622394448615721, 'alpha': 0.0031855256368657063, 'lambda': 1.4536641434803834}. Best is trial 1 with value: 0.6943699731903485.
# /tmp/ipykernel_33/3344094164.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.3),
# /tmp/ipykernel_33/3344094164.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_33/3344094164.py:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 10.0),
# /tmp/ipykernel_33/3344094164.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 10.0),
# [I 2024-06-03 13:42:46,616] Trial 7 finished with value: 0.6863270777479893 and parameters: {'max_depth': 11, 'learning_rate': 0.1626991475900462, 'n_estimators': 57, 'gamma': 2.1500824367014564e-08, 'min_child_weight': 1, 'subsample': 0.9451671104906542, 'colsample_bytree': 0.885531054398367, 'alpha': 1.297447620459767, 'lambda': 9.509901849241801e-05}. Best is trial 1 with value: 0.6943699731903485.
# /tmp/ipykernel_33/3344094164.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.3),
# /tmp/ipykernel_33/3344094164.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_33/3344094164.py:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 10.0),
# /tmp/ipykernel_33/3344094164.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 10.0),
# [I 2024-06-03 13:42:48,290] Trial 8 finished with value: 0.6606664113366526 and parameters: {'max_depth': 5, 'learning_rate': 0.01968769998840654, 'n_estimators': 257, 'gamma': 6.160746657535795e-05, 'min_child_weight': 5, 'subsample': 0.98901644826599, 'colsample_bytree': 0.5526403657847595, 'alpha': 0.16489781019425304, 'lambda': 0.007652585319406503}. Best is trial 1 with value: 0.6943699731903485.
# /tmp/ipykernel_33/3344094164.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.3),
# /tmp/ipykernel_33/3344094164.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_33/3344094164.py:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 10.0),
# /tmp/ipykernel_33/3344094164.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 10.0),
# [I 2024-06-03 13:42:51,897] Trial 9 finished with value: 0.6361547299885102 and parameters: {'max_depth': 14, 'learning_rate': 0.0021786747832248598, 'n_estimators': 145, 'gamma': 0.0009212030355150657, 'min_child_weight': 1, 'subsample': 0.7289507015559546, 'colsample_bytree': 0.8861400673495485, 'alpha': 9.724022973754673, 'lambda': 0.1786624129580384}. Best is trial 1 with value: 0.6943699731903485.
# /tmp/ipykernel_33/3344094164.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.3),
# /tmp/ipykernel_33/3344094164.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_33/3344094164.py:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 10.0),
# /tmp/ipykernel_33/3344094164.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 10.0),
# [I 2024-06-03 13:42:55,026] Trial 10 finished with value: 0.6890080428954424 and parameters: {'max_depth': 7, 'learning_rate': 0.06268566668400356, 'n_estimators': 384, 'gamma': 2.2861534972249232e-06, 'min_child_weight': 7, 'subsample': 0.8450953548900295, 'colsample_bytree': 0.647327437438624, 'alpha': 1.191823817929525e-08, 'lambda': 4.0687570142325896e-08}. Best is trial 1 with value: 0.6943699731903485.
# /tmp/ipykernel_33/3344094164.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.3),
# /tmp/ipykernel_33/3344094164.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_33/3344094164.py:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 10.0),
# /tmp/ipykernel_33/3344094164.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 10.0),
# [I 2024-06-03 13:42:58,273] Trial 11 finished with value: 0.6897740329375718 and parameters: {'max_depth': 7, 'learning_rate': 0.0613429133061022, 'n_estimators': 390, 'gamma': 1.8813056376861336e-06, 'min_child_weight': 7, 'subsample': 0.8465462217939465, 'colsample_bytree': 0.6619131205000495, 'alpha': 1.984034094511324e-07, 'lambda': 1.7220622685253864e-08}. Best is trial 1 with value: 0.6943699731903485.
# /tmp/ipykernel_33/3344094164.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.3),
# /tmp/ipykernel_33/3344094164.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_33/3344094164.py:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 10.0),
# /tmp/ipykernel_33/3344094164.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 10.0),
# [I 2024-06-03 13:43:01,244] Trial 12 finished with value: 0.6893910379165071 and parameters: {'max_depth': 8, 'learning_rate': 0.03545484400319718, 'n_estimators': 340, 'gamma': 0.9072895905876853, 'min_child_weight': 7, 'subsample': 0.8513541182969859, 'colsample_bytree': 0.6764557228066306, 'alpha': 2.2730361936679708e-05, 'lambda': 5.183952193075564e-07}. Best is trial 1 with value: 0.6943699731903485.
# /tmp/ipykernel_33/3344094164.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.3),
# /tmp/ipykernel_33/3344094164.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_33/3344094164.py:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 10.0),
# /tmp/ipykernel_33/3344094164.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 10.0),
# [I 2024-06-03 13:43:03,348] Trial 13 finished with value: 0.679816162389889 and parameters: {'max_depth': 6, 'learning_rate': 0.2879082527682738, 'n_estimators': 320, 'gamma': 4.912831502030283e-06, 'min_child_weight': 7, 'subsample': 0.837297145089258, 'colsample_bytree': 0.6831768732065606, 'alpha': 0.02625572011921054, 'lambda': 1.737081637509131e-07}. Best is trial 1 with value: 0.6943699731903485.
# /tmp/ipykernel_33/3344094164.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.3),
# /tmp/ipykernel_33/3344094164.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_33/3344094164.py:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 10.0),
# /tmp/ipykernel_33/3344094164.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 10.0),
# [I 2024-06-03 13:43:08,236] Trial 14 finished with value: 0.6928379931060896 and parameters: {'max_depth': 9, 'learning_rate': 0.06535857710065027, 'n_estimators': 338, 'gamma': 2.7478229997169857e-06, 'min_child_weight': 4, 'subsample': 0.7412506981638971, 'colsample_bytree': 0.9575966116803545, 'alpha': 3.258492865686907e-06, 'lambda': 1.8080138537630203e-08}. Best is trial 1 with value: 0.6943699731903485.
# /tmp/ipykernel_33/3344094164.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.3),
# /tmp/ipykernel_33/3344094164.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_33/3344094164.py:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 10.0),
# /tmp/ipykernel_33/3344094164.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 10.0),
# [I 2024-06-03 13:43:12,628] Trial 15 finished with value: 0.6890080428954424 and parameters: {'max_depth': 9, 'learning_rate': 0.08855890658085784, 'n_estimators': 325, 'gamma': 0.1338034411213975, 'min_child_weight': 4, 'subsample': 0.7255979889901223, 'colsample_bytree': 0.9781286185889354, 'alpha': 7.580654767679743e-06, 'lambda': 4.581584699237933e-06}. Best is trial 1 with value: 0.6943699731903485.
# /tmp/ipykernel_33/3344094164.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.3),
# /tmp/ipykernel_33/3344094164.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_33/3344094164.py:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 10.0),
# /tmp/ipykernel_33/3344094164.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 10.0),
# [I 2024-06-03 13:43:13,918] Trial 16 finished with value: 0.6422826503255458 and parameters: {'max_depth': 3, 'learning_rate': 0.02239186669737636, 'n_estimators': 280, 'gamma': 3.675347975805087e-05, 'min_child_weight': 3, 'subsample': 0.7745200700243323, 'colsample_bytree': 0.9908748705344534, 'alpha': 1.8782783962817728e-06, 'lambda': 2.299078659009005e-07}. Best is trial 1 with value: 0.6943699731903485.
# /tmp/ipykernel_33/3344094164.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.3),
# /tmp/ipykernel_33/3344094164.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_33/3344094164.py:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 10.0),
# /tmp/ipykernel_33/3344094164.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 10.0),
# [I 2024-06-03 13:43:22,650] Trial 17 finished with value: 0.686710072769054 and parameters: {'max_depth': 10, 'learning_rate': 0.011187248664962235, 'n_estimators': 355, 'gamma': 3.4527969564262546e-07, 'min_child_weight': 4, 'subsample': 0.6953740133132043, 'colsample_bytree': 0.7491039509611529, 'alpha': 0.0002449415768265949, 'lambda': 1.337701895725397e-05}. Best is trial 1 with value: 0.6943699731903485.
# /tmp/ipykernel_33/3344094164.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.3),
# /tmp/ipykernel_33/3344094164.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_33/3344094164.py:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 10.0),
# /tmp/ipykernel_33/3344094164.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 10.0),
# [I 2024-06-03 13:43:25,729] Trial 18 finished with value: 0.6878590578322482 and parameters: {'max_depth': 9, 'learning_rate': 0.033910120841978524, 'n_estimators': 162, 'gamma': 2.111675887534507e-05, 'min_child_weight': 6, 'subsample': 0.9093143249895452, 'colsample_bytree': 0.9436650894698562, 'alpha': 0.019776784945455803, 'lambda': 0.0018695260958337288}. Best is trial 1 with value: 0.6943699731903485.
# /tmp/ipykernel_33/3344094164.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.3),
# /tmp/ipykernel_33/3344094164.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_33/3344094164.py:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 10.0),
# /tmp/ipykernel_33/3344094164.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 10.0),
# [I 2024-06-03 13:43:29,382] Trial 19 finished with value: 0.6874760628111835 and parameters: {'max_depth': 8, 'learning_rate': 0.11272793950367004, 'n_estimators': 299, 'gamma': 0.0005491931814584982, 'min_child_weight': 2, 'subsample': 0.8051574346471749, 'colsample_bytree': 0.7691843062240837, 'alpha': 3.0833372987620486e-08, 'lambda': 1.2058995575741302e-08}. Best is trial 1 with value: 0.6943699731903485.
# /tmp/ipykernel_33/3344094164.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.3),
# /tmp/ipykernel_33/3344094164.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_33/3344094164.py:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 10.0),
# /tmp/ipykernel_33/3344094164.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 10.0),
# [I 2024-06-03 13:43:36,726] Trial 20 finished with value: 0.6886250478743776 and parameters: {'max_depth': 12, 'learning_rate': 0.04180585986491893, 'n_estimators': 351, 'gamma': 2.0134536465788478e-07, 'min_child_weight': 4, 'subsample': 0.6738905387177789, 'colsample_bytree': 0.9215089919748423, 'alpha': 3.839526818022635e-05, 'lambda': 0.027437411024329564}. Best is trial 1 with value: 0.6943699731903485.
# /tmp/ipykernel_33/3344094164.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.3),
# /tmp/ipykernel_33/3344094164.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_33/3344094164.py:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 10.0),
# ...
# /tmp/ipykernel_33/3344094164.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.3),
# /tmp/ipykernel_33/3344094164.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_33/3344094164.py:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 10.0),
# /tmp/ipykernel_33/3344094164.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 10.0),
# [I 2024-06-03 13:54:39,884] Trial 143 finished with value: 0.6955189582535427 and parameters: {'max_depth': 9, 'learning_rate': 0.07097959332815389, 'n_estimators': 354, 'gamma': 0.00025436665638626284, 'min_child_weight': 7, 'subsample': 0.8211775724468289, 'colsample_bytree': 0.9614371147371341, 'alpha': 1.5992458956438541e-06, 'lambda': 0.31864307064525965}. Best is trial 57 with value: 0.7004978935273841.
# /tmp/ipykernel_33/3344094164.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.3),
# /tmp/ipykernel_33/3344094164.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_33/3344094164.py:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 10.0),
# /tmp/ipykernel_33/3344094164.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 10.0),
# [I 2024-06-03 13:54:44,046] Trial 144 finished with value: 0.6905400229797013 and parameters: {'max_depth': 8, 'learning_rate': 0.054182889313878255, 'n_estimators': 386, 'gamma': 0.00045811701092165563, 'min_child_weight': 8, 'subsample': 0.852212811406388, 'colsample_bytree': 0.9409881805402917, 'alpha': 1.375531724478311e-07, 'lambda': 0.23843476029103688}. Best is trial 57 with value: 0.7004978935273841.
# /tmp/ipykernel_33/3344094164.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.3),
# /tmp/ipykernel_33/3344094164.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_33/3344094164.py:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 10.0),
# /tmp/ipykernel_33/3344094164.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 10.0),
# [I 2024-06-03 13:54:49,386] Trial 145 finished with value: 0.6916890080428955 and parameters: {'max_depth': 10, 'learning_rate': 0.046513531312791706, 'n_estimators': 369, 'gamma': 0.0001752886565080394, 'min_child_weight': 8, 'subsample': 0.8366809367099308, 'colsample_bytree': 0.9993753619290975, 'alpha': 0.00022573309383167736, 'lambda': 0.4126945888562924}. Best is trial 57 with value: 0.7004978935273841.
# /tmp/ipykernel_33/3344094164.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.3),
# /tmp/ipykernel_33/3344094164.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_33/3344094164.py:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 10.0),
# /tmp/ipykernel_33/3344094164.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 10.0),
# [I 2024-06-03 13:54:53,490] Trial 146 finished with value: 0.6897740329375718 and parameters: {'max_depth': 9, 'learning_rate': 0.03608274935858422, 'n_estimators': 273, 'gamma': 0.00013329794591694102, 'min_child_weight': 7, 'subsample': 0.880197911421477, 'colsample_bytree': 0.9700708655404846, 'alpha': 4.7726992476384125e-06, 'lambda': 0.14660754083418134}. Best is trial 57 with value: 0.7004978935273841.
# /tmp/ipykernel_33/3344094164.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.3),
# /tmp/ipykernel_33/3344094164.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_33/3344094164.py:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 10.0),
# /tmp/ipykernel_33/3344094164.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 10.0),
# [I 2024-06-03 13:54:58,853] Trial 147 finished with value: 0.693603983148219 and parameters: {'max_depth': 9, 'learning_rate': 0.061286183079473894, 'n_estimators': 380, 'gamma': 0.0004660727949959118, 'min_child_weight': 7, 'subsample': 0.8125111085086725, 'colsample_bytree': 0.9548564535076943, 'alpha': 4.5456854794383145e-07, 'lambda': 0.07012650601314149}. Best is trial 57 with value: 0.7004978935273841.
# /tmp/ipykernel_33/3344094164.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.3),
# /tmp/ipykernel_33/3344094164.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_33/3344094164.py:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 10.0),
# /tmp/ipykernel_33/3344094164.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 10.0),
# [I 2024-06-03 13:55:04,051] Trial 148 finished with value: 0.686710072769054 and parameters: {'max_depth': 8, 'learning_rate': 0.07889964116237148, 'n_estimators': 360, 'gamma': 0.0007696508426323946, 'min_child_weight': 6, 'subsample': 0.7864232870889419, 'colsample_bytree': 0.9899433653069047, 'alpha': 2.5066681671968616, 'lambda': 0.00021737814567053095}. Best is trial 57 with value: 0.7004978935273841.
# /tmp/ipykernel_33/3344094164.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.3),
# /tmp/ipykernel_33/3344094164.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_33/3344094164.py:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# /tmp/ipykernel_33/3344094164.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 10.0),
# /tmp/ipykernel_33/3344094164.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 10.0),
# [I 2024-06-03 13:55:09,871] Trial 149 finished with value: 0.7001148985063195 and parameters: {'max_depth': 10, 'learning_rate': 0.04082893579723249, 'n_estimators': 400, 'gamma': 0.0003013312319464229, 'min_child_weight': 8, 'subsample': 0.8599011448477344, 'colsample_bytree': 0.9668289538239486, 'alpha': 2.3778456894636908e-06, 'lambda': 0.009333556737145816}. Best is trial 57 with value: 0.7004978935273841.
# Best hyperparameters:  {'max_depth': 9, 'learning_rate': 0.053315078266350784, 'n_estimators': 391, 'gamma': 0.0017250476222867605, 'min_child_weight': 4, 'subsample': 0.8973067573902883, 'colsample_bytree': 0.984662961762766, 'alpha': 1.7769265331564559, 'lambda': 2.7743277275383336e-08}

# %%
study.best_params
# Out:
# {'max_depth': 9,
#  'learning_rate': 0.053315078266350784,
#  'n_estimators': 391,
#  'gamma': 0.0017250476222867605,
#  'min_child_weight': 4,
#  'subsample': 0.8973067573902883,
#  'colsample_bytree': 0.984662961762766,
#  'alpha': 1.7769265331564559,
#  'lambda': 2.7743277275383336e-08}

# %%
# Train the final model using the best hyperparameters
best_params = study.best_params
best_params['objective'] = 'multi:softmax'
best_params['num_class'] = 3

final_model = XGBClassifier(**best_params)
final_model.fit(X_train, y_train)

# Load test dataset
test = pd.read_csv('/kaggle/input/forest-type-classification-spai/test.csv')

# Drop the 'id' column to match training data features
# X_test_final = test.drop('id', axis=1)

# Make predictions on the test set
test_predictions = final_model.predict(test)

# Convert numeric predictions back to original string labels
test_predictions_labels = label_encoder.inverse_transform(test_predictions)

# Load sample submission file
sample_submission = pd.read_csv('/kaggle/input/forest-type-classification-spai/sample_submission.csv')

# Create submission DataFrame
submission = pd.DataFrame({'id': test['id'], 'nforest_type': test_predictions_labels})

# %%
submission
# Out:
#          id nforest_type
# 0     13467          DEF
# 1     12719          MDF
# 2      1054          MDF
# 3     13747          DDF
# 4      9453          DEF
# ...     ...          ...
# 3995    115          MDF
# 3996  10654          MDF
# 3997   5718          DDF
# 3998  13054          MDF
# 3999   6539          DEF
#
# [4000 rows x 2 columns]

# %%
# # Save the submission DataFrame to a CSV file
submission.to_csv('submission-XGBoost+Hparameter.csv', index=False)
